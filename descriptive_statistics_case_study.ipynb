# %% [markdown]
# # Load the CSV file into table format and find the shape of the data frame.

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\UPGRAD\ASSIGNMENT\probabylity and statistics\descriptive-case study\nutrition_1.csv")
df
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 0                0           0
# 1                1           1
# 2                2           2
# 3                3           3
# 4                4           4
# ...            ...         ...
# 8784          8784        8784
# 8785          8785        8785
# 8786          8786        8786
# 8787          8787        8787
# 8788          8788        8788
#
#                                                    name serving_size  \
# 0                                            Cornstarch        100 g
# 1                                          Nuts, pecans        100 g
# 2                                         Eggplant, raw        100 g
# 3                                        Teff, uncooked        100 g
# 4                                       Sherbet, orange        100 g
# ...                                                 ...          ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# ...

# %%
df.shape
# Out:
# (8789, 78)

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0             name serving_size  calories  \
# 0             0           0       Cornstarch        100 g       381
# 1             1           1     Nuts, pecans        100 g       691
# 2             2           2    Eggplant, raw        100 g        25
# 3             3           3   Teff, uncooked        100 g       367
# 4             4           4  Sherbet, orange        100 g       144
#
#    total_fat  saturated_fat  cholesterol  sodium  choline  ...      fat  \
# 0        0.1            NaN          0.0     9.0   0.4 mg  ...   0.05 g
# 1       72.0            6.2          0.0     0.0  40.5 mg  ...  71.97 g
# 2        0.2            NaN          0.0     2.0   6.9 mg  ...   0.18 g
# 3        2.4            0.4          0.0    12.0  13.1 mg  ...   2.38 g
# 4        2.0            1.2          1.0    46.0   7.7 mg  ...   2.00 g
#
#    saturated_fatty_acids monounsaturated_fatty_acids  \
# 0                  0.009                     0.016 g
# ...

# %% [markdown]
# # Removing unnecessary columns named "Unnamed: 0", "Unnamed: 0.1", lucopene, and "Serving_Size"

# %%
df1 = df.drop(['Unnamed: 0.1','Unnamed: 0','serving_size'], axis=1)

# %%
df1
# Out:
#                                                    name  calories  total_fat  \
# 0                                            Cornstarch       381        0.1
# 1                                          Nuts, pecans       691       72.0
# 2                                         Eggplant, raw        25        0.2
# 3                                        Teff, uncooked       367        2.4
# 4                                       Sherbet, orange       144        2.0
# ...                                                 ...       ...        ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...       125        3.5
# 8785  Lamb, cooked, separable lean only, composite o...       206        8.9
# 8786  Lamb, raw, separable lean and fat, composite o...       277       23.0
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...       121        3.0
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...       121        3.0
#
# ...

# %% [markdown]
# # Checking the Null and Duplicate values which are present in the dataset and removing them

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# name            0
# serving_size    0
# calories        0
#                ..
# alcohol         0
# ash             0
# caffeine        0
# theobromine     0
# water           0
# Length: 78, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # mean of all numeric features.

# %%
import statistics

# %%
mean = df1.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8612\2587741797.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean = df1.mean()

# %%
mean
# Out:
# calories                 226.283878
# total_fat                 10.556855
# saturated_fat              4.192791
# cholesterol               38.723063
# sodium                   306.353851
# folic_acid                17.638639
# vitamin_a                676.320514
# lucopene                   0.000000
# vitamin_b12                1.201716
# vitamin_b6                 0.261324
# vitamin_c                  8.356548
# vitamin_d                 14.560815
# vitamin_e                  0.885576
# calcium                   73.317328
# irom                       2.645764
# protein                   11.345616
# carbohydrate              22.121915
# fiber                      2.040073
# sugars                     6.756293
# fructose                   0.267262
# galactose                  0.004852
# glucose                    0.290416
# lactose                    0.132518
# maltose                    0.071506
# sucrose                    0.577029
# saturated_fatty_acids      3.434146
# ...

# %% [markdown]
# # maximum and minimum values for the alcohol column

# %%
minimum = df1['alcohol'].min()

# %%
minimum
# Out:
# 0.0

# %%
maximum = df1['alcohol'].max()

# %%
maximum
# Out:
# 42.5

# %% [markdown]
# # unique values present in the choline

# %%
unique = df1['choline'].unique()

# %%
unique
# Out:
# array(['0.4 mg', '40.5 mg', '6.9 mg', ..., '131.3 mg', '116.9 mg',
#        '109.8 mg'], dtype=object)

# %% [markdown]
# # standard deviation for features, fiber, folic_acid, lucopene

# %%
df1.std()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8612\3039516898.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.std()
# calories                  169.862001
# total_fat                  15.818247
# saturated_fat               6.877009
# cholesterol               117.358944
# sodium                    939.220468
# folic_acid                100.736270
# vitamin_a                3694.739553
# lucopene                    0.000000
# vitamin_b12                 4.271908
# vitamin_b6                  0.467713
# vitamin_c                  65.624854
# vitamin_d                 123.643892
# vitamin_e                   3.813260
# calcium                   199.850425
# irom                        5.661046
# protein                    10.530602
# carbohydrate               27.266261
# fiber                       4.269181
# ...

# %%
df1['folic_acid'].std()
# Out:
# 100.73627014026262

# %%
df1['lucopene'].std()
# Out:
# 0.0

# %%
df1['fiber'].std()
# Out:
# 4.269181010869626

# %% [markdown]
# # variance for total_fat to get how total_fat is varying among different food items.

# %%
df1['total_fat'].var()
# Out:
# 250.21695260316247

# %%
df1.var()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8612\2870725145.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.var()
# calories                 2.885310e+04
# total_fat                2.502170e+02
# saturated_fat            4.729325e+01
# cholesterol              1.377312e+04
# sodium                   8.821351e+05
# folic_acid               1.014780e+04
# vitamin_a                1.365110e+07
# lucopene                 0.000000e+00
# vitamin_b12              1.824920e+01
# vitamin_b6               2.187557e-01
# vitamin_c                4.306621e+03
# vitamin_d                1.528781e+04
# vitamin_e                1.454095e+01
# calcium                  3.994019e+04
# irom                     3.204744e+01
# protein                  1.108936e+02
# carbohydrate             7.434490e+02
# ...

# %% [markdown]
# # correlation between different features available in the dataset.

# %%
df1.corr()
# Out:
#                        calories  total_fat  saturated_fat  cholesterol  \
# calories               1.000000   0.806574       0.613212     0.015153
# total_fat              0.806574   1.000000       0.759576     0.087367
# saturated_fat          0.613212   0.759576       1.000000     0.056382
# cholesterol            0.015153   0.087367       0.056382     1.000000
# sodium                 0.055405   0.011999      -0.013882    -0.018300
# folic_acid             0.137879  -0.047441      -0.064756    -0.051275
# vitamin_a             -0.029758  -0.020500      -0.022144     0.085757
# lucopene                    NaN        NaN            NaN          NaN
# vitamin_b12           -0.014267  -0.020698      -0.040535     0.322310
# vitamin_b6             0.118680  -0.041975      -0.108407     0.034698
# vitamin_c             -0.033269  -0.057288      -0.038787    -0.028347
# vitamin_d              0.074744   0.073238       0.036310     0.064323
# ...

# %% [markdown]
# # distribution of columns, sugars, total_fat, water, and protein by plotting the histogram.

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
df1['total_fat'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['sugars'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['protein'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['water'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # skewness and kurtosis for all the numeric features available in the dataset.

# %%
df1.skew()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8612\149261804.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.skew()
# calories                  1.149091
# total_fat                 3.309571
# saturated_fat             6.352441
# cholesterol              15.322120
# sodium                   22.541058
# folic_acid               10.960558
# vitamin_a                15.455765
# lucopene                  0.000000
# vitamin_b12              13.215218
# vitamin_b6                7.690288
# vitamin_c                29.556392
# vitamin_d                61.152034
# vitamin_e                13.894348
# calcium                  13.464522
# irom                      6.972293
# protein                   1.165780
# carbohydrate              1.127907
# fiber                     5.807997
# sugars                    2.908293
# ...

# %%
df1.kurtosis()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8612\3614614862.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.kurtosis()
# calories                    1.713243
# total_fat                  13.754812
# saturated_fat              63.427511
# cholesterol               313.379845
# sodium                    681.887714
# folic_acid                173.398893
# vitamin_a                 309.239687
# lucopene                    0.000000
# vitamin_b12               227.509099
# vitamin_b6                107.160607
# vitamin_c                1003.773962
# vitamin_d                4848.568195
# vitamin_e                 343.153409
# calcium                   342.850439
# irom                       73.007119
# protein                     2.646117
# carbohydrate               -0.146919
# ...
